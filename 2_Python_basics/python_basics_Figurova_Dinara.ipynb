# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

# %%
len(long_phrase) > len(short_phrase)
# Out:
# True

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах (*в мегабайте 2^20 байт*). Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*".

# %%
vol = 224059719.68
vol = vol/(2**20)
print( "Объем файла равен", vol, "Mb")
# Out:
# Объем файла равен 213.68 Mb

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
print("Узнай свой знак Зодиака")
q = str(input("Введите месяц: "))
w = int(input("Введите число: "))
if q == "март" and w >= 21 and w <= 31:
    print("Вывод: Овен")
elif q == "апрель" and w >= 1 and w <= 20:
    print("Вывод: Овен")
elif q == "апрель" and w >= 21 and w <= 31:
    print("Вывод: Телец")
elif q == "май" and w >= 1 and w <= 20:
    print("Вывод: Телец")
elif q == "май" and w >= 21 and w <= 31:
    print("Вывод: Близнецы")
elif q == "июнь" and w >= 1 and w <= 21:
    print("Вывод: Близнецы")
elif q == "июнь" and w >= 22 and w <= 31:
    print("Вывод: Рак")
elif q == "июль" and w >= 1 and w <= 22:
    print("Вывод: Рак")
elif q == "июль" and w >= 23 and w <= 31:
    print("Вывод: Лев")
elif q == "август" and w >= 1 and w <= 23:
    print("Вывод: Лев")
elif q == "август" and w >= 24 and w <= 31:
    print("Вывод: Дева")
elif q == "сентябрь" and w >= 1 and w <= 23:
    print("Вывод: Дева")
elif q == "сентябрь" and w >= 24 and w <= 31:
    print("Вывод: Весы")
elif q == "октябрь" and w >= 1 and w <= 23:
    print("Вывод: Весы")
elif q == "октябрь" and w >= 24 and w <= 31:
    print("Вывод: Скорпион")
elif q == "ноябрь" and w >= 1 and w <= 22:
    print("Вывод: Скорпион")
elif q == "ноябрь" and w >= 23 and w <= 31:
    print("Вывод: Стрелец")
elif q == "декабрь" and w >= 1 and w <= 21:
    print("Вывод: Стрелец")
elif q == "декабрь" and w >= 22 and w <= 31:
    print("Вывод: Козерог")
elif q == "январь" and w >= 1 and w <= 20:
    print("Вывод: Козерог")
elif q == "январь" and w >= 21 and w <= 31:
    print("Вывод: Водолей")
elif q == "февраль" and w >= 1 and w <= 20:
    print("Вывод: Водолей")
elif q == "февраль" and w >= 21 and w <= 31:
    print("Вывод: Рыбы")
elif q == "март" and w >= 1 and w <= 20:
    print("Вывод: Рыбы")
# Out:
# Узнай свой знак Зодиака
# Введите месяц: июнь
# Введите число: 1
# Вывод: Близнецы

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
salary = int(input("Введите заработанную плату в месяц: "))
percent_i = int(input("Введите сколько процентов уходит на ипотеку: "))
percent_l = int(input("Введите сколько процентов уходит на жизнь: "))
bonus_q = int(input("Введите количество премий за год: "))
total = salary * (12 + bonus_q)
ipoteka = salary * 12 * percent_i / 100
saving = total * (1 - percent_l / 100) - ipoteka
print ("Вывод: На ипотеку было потрачено:", ipoteka,"рублей. Было накоплено:", saving,"рублей")
# Out:
# Введите заработанную плату в месяц: 50000
# Введите сколько процентов уходит на ипотеку: 20
# Введите сколько процентов уходит на жизнь: 40
# Введите количество премий за год: 3
# Вывод: На ипотеку было потрачено: 120000.0 рублей. Было накоплено: 330000.0 рублей
